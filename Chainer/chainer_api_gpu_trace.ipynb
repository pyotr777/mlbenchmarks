# %% [markdown]
# # Chainer CIFAR100 GPU and API trace
#
# ### Profiled with
# ```
# 22Feb1713peter@mouse:~$ ./profile_cifar.sh --print-gpu-trace --print-api-trace --csv --log-file chainer_api_gpu_trace.csv```
#
# batch size 128, epoch 1
#
# [nvprof docs](http://docs.nvidia.com/cuda/profiler-users-guide/index.html#gpu-trace-and-api-trace-modes)

# %%
# %matplotlib inline
import re
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import os.path
import datetime
from cycler import cycler
import pandas as pd

# %%
# !ls *.csv
# Out:
# K80_cifar_b128_metrics.csv
# chainer_api_gpu_trace.csv
# chainer_mouse_flops_nvvp_export.csv
# chainer_trace_mouse_flops.csv
# kernel_export.csv
# mouse_cifar_b128_metrics.csv
# nvidia-smi-chainer_mouse_combined.csv
# nvidia-smi-chainer_mouse_nvsmi_25.csv
# nvidia-smi-chainer_mouse_nvsmi_50.csv
# nvprof-trace-chainer_mouse_combined-29174.csv

# %%
filename="chainer_api_gpu_trace.csv"
nvprof = pd.read_csv(filename, header=[0,1], skiprows=[0,1,2])
nvprof.iloc[:5]
# Out:
#       Start  Duration             Grid X             Grid Y  \
#           s        ms Unnamed: 2_level_1 Unnamed: 3_level_1
# 0  0.112938  0.001085                NaN                NaN
# 1  0.112939  0.000115                NaN                NaN
# 2  0.113051  0.000452                NaN                NaN
# 3  0.113052  0.000329                NaN                NaN
# 4  0.113069  0.000153                NaN                NaN
#
#               Grid Z            Block X            Block Y            Block Z  \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1 Unnamed: 7_level_1
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#   Registers Per Thread Static SMem Dynamic SMem Size Throughput  \
#     Unnamed: 8_level_1          KB           KB   MB       GB/s
# 0                  NaN         NaN          NaN  NaN        NaN
# 1                  NaN         NaN          NaN  NaN        NaN
# 2                  NaN         NaN          NaN  NaN        NaN
# 3                  NaN         NaN          NaN  NaN        NaN
# 4                  NaN         NaN          NaN  NaN        NaN
#
#            SrcMemType          DstMemType              Device  \
#   Unnamed: 13_level_1 Unnamed: 14_level_1 Unnamed: 15_level_1
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#               Context              Stream                  Name
#   Unnamed: 16_level_1 Unnamed: 17_level_1   Unnamed: 18_level_1
# 0                 NaN                 NaN      cuDeviceGetCount
# 1                 NaN                 NaN      cuDeviceGetCount
# 2                 NaN                 NaN           cuDeviceGet
# 3                 NaN                 NaN  cuDeviceGetAttribute
# 4                 NaN                 NaN  cuDeviceGetAttribute

# %% [markdown]
# ### Rename columns and Multiindex change to 1 level names

# %%
print nvprof.columns.levels[0]
print nvprof.columns.levels[1]
print nvprof.columns.labels[0]
print nvprof.columns.labels[1]
# Out:
# Index([u'Block X', u'Block Y', u'Block Z', u'Context', u'Device',
#        u'DstMemType', u'Duration', u'Dynamic SMem', u'Grid X', u'Grid Y',
#        u'Grid Z', u'Name', u'Registers Per Thread', u'Size', u'SrcMemType',
#        u'Start', u'Static SMem', u'Stream', u'Throughput'],
#       dtype='object')
# Index([u'GB/s', u'KB', u'MB', u'Unnamed: 13_level_1', u'Unnamed: 14_level_1',
#        u'Unnamed: 15_level_1', u'Unnamed: 16_level_1', u'Unnamed: 17_level_1',
#        u'Unnamed: 18_level_1', u'Unnamed: 2_level_1', u'Unnamed: 3_level_1',
#        u'Unnamed: 4_level_1', u'Unnamed: 5_level_1', u'Unnamed: 6_level_1',
#        u'Unnamed: 7_level_1', u'Unnamed: 8_level_1', u'ms', u's'],
#       dtype='object')
# FrozenNDArray([15, 6, 8, 9, 10, 0, 1, 2, 12, 16, 7, 13, 18, 14, 5, 4, 3, 17, 11], dtype='int8')
# FrozenNDArray([17, 16, 9, 10, 11, 12, 13, 14, 15, 1, 1, 2, 0, 3, 4, 5, 6, 7, 8], dtype='int8')

# %%
columns = []
names = nvprof.columns.levels[0]
names2 = nvprof.columns.levels[1]
for i in range(len(nvprof.columns.labels[0])):
    name = names[nvprof.columns.labels[0][i]]
    name2= names2[nvprof.columns.labels[1][i]]
    if "Unnamed" not in name2:
        name +=" ("+name2+")"
    columns.append(name)
print columns
# Out:
# ['Start (s)', 'Duration (ms)', 'Grid X', 'Grid Y', 'Grid Z', 'Block X', 'Block Y', 'Block Z', 'Registers Per Thread', 'Static SMem (KB)', 'Dynamic SMem (KB)', 'Size (MB)', 'Throughput (GB/s)', 'SrcMemType', 'DstMemType', 'Device', 'Context', 'Stream', 'Name']

# %%
nvprof.columns = columns

# %%
nvprof.iloc[:5]
# Out:
#    Start (s)  Duration (ms)  Grid X  Grid Y  Grid Z  Block X  Block Y  \
# 0   0.112938       0.001085     NaN     NaN     NaN      NaN      NaN
# 1   0.112939       0.000115     NaN     NaN     NaN      NaN      NaN
# 2   0.113051       0.000452     NaN     NaN     NaN      NaN      NaN
# 3   0.113052       0.000329     NaN     NaN     NaN      NaN      NaN
# 4   0.113069       0.000153     NaN     NaN     NaN      NaN      NaN
#
#    Block Z  Registers Per Thread  Static SMem (KB)  Dynamic SMem (KB)  \
# 0      NaN                   NaN               NaN                NaN
# 1      NaN                   NaN               NaN                NaN
# 2      NaN                   NaN               NaN                NaN
# 3      NaN                   NaN               NaN                NaN
# 4      NaN                   NaN               NaN                NaN
#
#    Size (MB)  Throughput (GB/s) SrcMemType DstMemType Device  Context  Stream  \
# 0        NaN                NaN        NaN        NaN    NaN      NaN     NaN
# 1        NaN                NaN        NaN        NaN    NaN      NaN     NaN
# 2        NaN                NaN        NaN        NaN    NaN      NaN     NaN
# 3        NaN                NaN        NaN        NaN    NaN      NaN     NaN
# 4        NaN                NaN        NaN        NaN    NaN      NaN     NaN
#
#                    Name
# 0      cuDeviceGetCount
# 1      cuDeviceGetCount
# 2           cuDeviceGet
# 3  cuDeviceGetAttribute
# 4  cuDeviceGetAttribute

# %%
nvprof.xs("Name",axis=1)
# Out:
# 0               cuDeviceGetCount
# 1               cuDeviceGetCount
# 2                    cuDeviceGet
# 3           cuDeviceGetAttribute
# 4           cuDeviceGetAttribute
# 5           cuDeviceGetAttribute
# 6               cuDeviceGetCount
# 7                    cuDeviceGet
# 8                cuDeviceGetName
# 9               cuDeviceTotalMem
# 10          cuDeviceGetAttribute
# 11          cuDeviceGetAttribute
# 12          cuDeviceGetAttribute
# 13          cuDeviceGetAttribute
# 14          cuDeviceGetAttribute
# 15          cuDeviceGetAttribute
# 16          cuDeviceGetAttribute
# 17          cuDeviceGetAttribute
# 18          cuDeviceGetAttribute
# 19          cuDeviceGetAttribute
# 20          cuDeviceGetAttribute
# 21          cuDeviceGetAttribute
# 22          cuDeviceGetAttribute
# 23          cuDeviceGetAttribute
# 24          cuDeviceGetAttribute
# 25          cuDeviceGetAttribute
# 26          cuDeviceGetAttribute
# 27          cuDeviceGetAttribute
# 28          cuDeviceGetAttribute
# 29          cuDeviceGetAttribute
#                    ...
# 1483565         cudaEventDestroy
# 1483566         cudaEventDestroy
# 1483567         cudaEventDestroy
# 1483568         cudaEventDestroy
# 1483569                 cudaFree
# 1483570                 cudaFree
# 1483571                 cudaFree
# 1483572                 cudaFree
# 1483573                 cudaFree
# 1483574                 cudaFree
# 1483575    cudaThreadSynchronize
# 1483576         cudaEventDestroy
# 1483577         cudaEventDestroy
# 1483578         cudaEventDestroy
# 1483579         cudaEventDestroy
# 1483580         cudaEventDestroy
# 1483581         cudaEventDestroy
# 1483582         cudaEventDestroy
# 1483583         cudaEventDestroy
# 1483584                 cudaFree
# 1483585    cudaThreadSynchronize
# 1483586         cudaEventDestroy
# 1483587         cudaEventDestroy
# 1483588         cudaEventDestroy
# 1483589         cudaEventDestroy
# 1483590         cudaEventDestroy
# 1483591         cudaEventDestroy
# 1483592         cudaEventDestroy
# 1483593         cudaEventDestroy
# 1483594                 cudaFree
# Name: Name, Length: 1483595, dtype: object

# %%
wgrad = nvprof[nvprof.Name.str.contains("wgrad_alg0_engine")]
wgrad.reset_index(inplace=True)
print wgrad["Name"].unique()
wgrad.iloc[:10]
# Out:
# [ 'cudaLaunch (void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*,'
#  'void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*, float const , kernel_grad_params, int, float, int, int, int, int) [3561]'
#  'cudaLaunch (void cudnn::detail::wgrad_alg0_engine<float, int=512, int=6, int=5, int=3, int=3, int=3, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=512, int=6, int=5, int=3, int=3, int=3, bool=1, int=512>*,'
#  ...,
#  'void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*, float const , kernel_grad_params, int, float, int, int, int, int) [1287747]'
#  'void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*, float const , kernel_grad_params, int, float, int, int, int, int) [1287850]'
#  'void cudnn::detail::wgrad_alg0_engine<float, int=512, int=6, int=5, int=3, int=3, int=3, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=512, int=6, int=5, int=3, int=3, int=3, bool=1, int=512>*, float const , kernel_grad_params, int, float, int, int, int, int) [1288836]']
#    index  Start (s)  Duration (ms)  Grid X  Grid Y  Grid Z  Block X  Block Y  \
# 0   3854   1.443855       0.033852     NaN     NaN     NaN      NaN      NaN
# 1   3957   1.444518       0.010972     NaN     NaN     NaN      NaN      NaN
# 2   4062   1.445149       0.010915     NaN     NaN     NaN      NaN      NaN
# 3   4267   1.446409      38.672432    72.0     2.0   128.0      8.0     32.0
# 4   5065   1.453125       0.022996     NaN     NaN     NaN      NaN      NaN
# 5   5083   1.486445      40.110806    72.0     2.0   128.0      8.0     32.0
# 6   5091   1.527918      39.381715    72.0     2.0   128.0      8.0     32.0
# 7   5182   1.650861       1.029093     1.0     2.0   256.0      8.0      8.0
# 8   7609   1.671483       0.020013     NaN     NaN     NaN      NaN      NaN
# 9   7712   1.672116       0.010760     NaN     NaN     NaN      NaN      NaN
#
#    Block Z  Registers Per Thread  Static SMem (KB)  Dynamic SMem (KB)  \
# 0      NaN                   NaN               NaN                NaN
# 1      NaN                   NaN               NaN                NaN
# 2      NaN                   NaN               NaN                NaN
# 3      1.0                 105.0             10.25                0.0
# 4      NaN                   NaN               NaN                NaN
# 5      1.0                 105.0             10.25                0.0
# 6      1.0                 105.0             10.25                0.0
# 7      1.0                  79.0              3.25                0.0
# 8      NaN                   NaN               NaN                NaN
# 9      NaN                   NaN               NaN                NaN
#
#    Size (MB)  Throughput (GB/s) SrcMemType DstMemType            Device  \
# 0        NaN                NaN        NaN        NaN               NaN
# 1        NaN                NaN        NaN        NaN               NaN
# 2        NaN                NaN        NaN        NaN               NaN
# 3        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 4        NaN                NaN        NaN        NaN               NaN
# 5        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 6        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 7        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 8        NaN                NaN        NaN        NaN               NaN
# 9        NaN                NaN        NaN        NaN               NaN
#
#    Context  Stream                                               Name
# 0      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...
# 1      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...
# 2      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...
# 3      1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 4      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...
# 5      1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 6      1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 7      1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 8      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...
# 9      NaN     NaN  cudaLaunch (void cudnn::detail::wgrad_alg0_eng...

# %%
wgrad.loc[2,"Name"]
# Out:
# 'cudaLaunch (void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*,'

# %%
wgrad.loc[3,"Name"]
# Out:
# 'void cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>(int, int, int, float const *, int, cudnn::detail::wgrad_alg0_engine<float, int=128, int=6, int=8, int=3, int=3, int=5, bool=1, int=512>*, float const , kernel_grad_params, int, float, int, int, int, int) [3561]'

# %%
# Search all dataframe for a keyword
def search_keyword(df,word):
    mask = np.column_stack([df[col].str.contains(word,na=False, regex=False) for col in df.select_dtypes([np.object])])
    return df[mask]

# %%
search_keyword(nvprof,"3561")
# Out:
#          Start (s)  Duration (ms)   Grid X  Grid Y  Grid Z  Block X  Block Y  \
# 4267      1.446409      38.672432     72.0     2.0   128.0      8.0     32.0
# 41970     3.709265       0.180417    256.0     1.0     1.0    512.0      1.0
# 148737   10.405964       0.010966      NaN     NaN     NaN      NaN      NaN
# 150508   10.509191       0.002240      1.0     1.0     1.0    128.0      1.0
# 201496   13.743434       0.006158      NaN     NaN     NaN      NaN      NaN
# 202958   13.752820       0.275553  32768.0     1.0     1.0    128.0      1.0
# 234397   15.757627       0.010283      NaN     NaN     NaN      NaN      NaN
# 237159   15.782674       0.040064     64.0     1.0     1.0     64.0      1.0
# 258405   17.109196       0.006447      NaN     NaN     NaN      NaN      NaN
# 258411   17.109225       0.006448      NaN     NaN     NaN      NaN      NaN
# 259058   17.309413       0.029856   2304.0     1.0     1.0    128.0      1.0
# 259059   17.309443       0.001248      1.0     1.0     1.0    128.0      1.0
# 368364   24.019453       0.008455      NaN     NaN     NaN      NaN      NaN
# 370898   24.052189       0.034784   2048.0     1.0     1.0    128.0      1.0
# 390814   25.366638       0.014401      NaN     NaN     NaN      NaN      NaN
# 390822   25.366742       0.009521      NaN     NaN     NaN      NaN      NaN
# 390874   25.367039       0.012021      NaN     NaN     NaN      NaN      NaN
# 390879   25.367053       0.004973      NaN     NaN     NaN      NaN      NaN
NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 259059         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 368364         NaN                NaN        NaN        NaN               NaN
# 370898         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 390814         NaN                NaN        NaN        NaN               NaN
# 390822         NaN                NaN        NaN        NaN               NaN
# 390874         NaN                NaN        NaN        NaN               NaN
# 390879         NaN                NaN        NaN        NaN               NaN
# 390883         NaN                NaN        NaN        NaN               NaN
# 392642         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392643         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392644         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392645         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392646         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392647         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 392648         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 409874         NaN                NaN        NaN        NaN               NaN
# 410801         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 479420         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 541770         NaN                NaN        NaN        NaN               NaN
# ...            ...                ...        ...        ...               ...
# 808162         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 808337         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 816239         NaN                NaN        NaN        NaN               NaN
# 819012         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 838174         NaN                NaN        NaN        NaN               NaN
# 840716         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 917307         NaN                NaN        NaN        NaN               NaN
# 917311         NaN                NaN        NaN        NaN               NaN
# 920196         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 920197         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 969783         NaN                NaN        NaN        NaN               NaN
# 970948         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 992654         NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1136655        NaN                NaN        NaN        NaN               NaN
# 1137268        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1244250        NaN                NaN        NaN        NaN               NaN
# 1245593        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1249102        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1299092        NaN                NaN        NaN        NaN               NaN
# 1299865        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1321024        NaN                NaN        NaN        NaN               NaN
# 1321588        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1342956        NaN                NaN        NaN        NaN               NaN
# 1343303        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1356285        NaN                NaN        NaN        NaN               NaN
# 1357627        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1366456        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1466704        NaN                NaN        NaN        NaN  Quadro P2000 (0)
# 1475137        NaN                NaN        NaN        NaN               NaN
# 1475252        NaN                NaN        NaN        NaN  Quadro P2000 (0)
#
#          Context  Stream                                               Name
# 4267         1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 41970        1.0     7.0  void cudnn::detail::bn_fw_tr_1C11_singleread<f...
# 148737       NaN     NaN  cudaLaunch (cudnn::maxwell::gemm::computeOffse...
# 150508       1.0     7.0  cudnn::maxwell::gemm::computeOffsetsKernel(cud...
# 201496       NaN     NaN    cuLaunchKernel (cupy_random_1_minus_x [183561])
# 202958       1.0     7.0                     cupy_random_1_minus_x [183561]
# 234397       NaN     NaN  cudaLaunch (void gen_sequenced<curandStateXORW...
# 237159       1.0     7.0  void gen_sequenced<curandStateXORWOW, float, i...
# 258405       NaN     NaN             cuLaunchKernel (weight_decay [235610])
# 258411       NaN     NaN             cuLaunchKernel (weight_decay [235616])
# 259058       1.0     7.0                              weight_decay [235610]
# 259059       1.0     7.0                              weight_decay [235616]
# 368364       NaN     NaN              cuLaunchKernel (dropout_fwd [335611])
# 370898       1.0     7.0                               dropout_fwd [335611]
# 390814       NaN     NaN            cuLaunchKernel (cupy_multiply [356122])
# 390822       NaN     NaN                 cuLaunchKernel (relu_bwd [356130])
# 390874       NaN     NaN  cudaLaunch (cudnn::maxwell::gemm::computeOffse...
# 390879       NaN     NaN  cudaLaunch (cudnn::maxwell::gemm::computeBOffs...
# 390883       NaN     NaN  cudaLaunch (maxwell_scudnn_128x128_stridedB_sm...
# 392642       1.0     7.0  void cudnn::detail::wgrad_alg0_engine<float, i...
# 392643       1.0     7.0                             cupy_multiply [356122]
# 392644       1.0     7.0                                  relu_bwd [356130]
# 392645       1.0     7.0  void cudnn::detail::bn_bw_1C11_singleread<floa...
# 392646       1.0     7.0  cudnn::maxwell::gemm::computeOffsetsKernel(cud...
# 392647       1.0     7.0  cudnn::maxwell::gemm::computeBOffsetsKernel(cu...
# 392648       1.0     7.0  maxwell_scudnn_128x128_stridedB_small_nn [356190]
# 409874       NaN     NaN  cudaLaunch (void cudnn::winograd::generateWino...
# 410801       1.0     7.0  void cudnn::winograd::generateWinogradTilesKer...
# 479420       1.0     7.0  void cudnn::detail::bn_bw_1C11_singleread<floa...
# 541770       NaN     NaN  cudaLaunch (maxwell_scudnn_128x128_relu_small_...
# ...          ...     ...                                                ...
# 808162       1.0     7.0  void cudnn::winograd::generateWinogradTilesKer...
# 808337       1.0     7.0  maxwell_scudnn_128x128_stridedB_splitK_small_n...
# 816239       NaN     NaN             cuLaunchKernel (cupy_maximum [743561])
# 819012       1.0     7.0                              cupy_maximum [743561]
# 838174       NaN     NaN  cudaLaunch (void gen_sequenced<curandStateXORW...
# 840716       1.0     7.0  void gen_sequenced<curandStateXORWOW, float, i...
# 917307       NaN     NaN  cudaLaunch (void cudnn::winograd::generateWino...
# 917311       NaN     NaN  cudaLaunch (maxwell_scudnn_winograd_128x128_ld...
# 920196       1.0     7.0  void cudnn::winograd::generateWinogradTilesKer...
# 920197       1.0     7.0  maxwell_scudnn_winograd_128x128_ldg1_ldg4_tile...
# 969783       NaN     NaN  cudaLaunch (cudnn::maxwell::gemm::computeBOffs...
# 970948       1.0     7.0  cudnn::maxwell::gemm::computeBOffsetsKernel(cu...
# 992654       1.0     7.0  void cudnn::detail::bn_bw_1C11_kernel_new<floa...
# 1136655      NaN     NaN            cuLaunchKernel (weight_decay [1035614])
# 1137268      1.0     7.0                             weight_decay [1035614]
# 1244250      NaN     NaN  cudaLaunch (maxwell_scudnn_128x128_stridedB_sp...
# 1245593      1.0     7.0  maxwell_scudnn_128x128_stridedB_splitK_small_n...
# 1249102      1.0     7.0  void cudnn::detail::bn_fw_tr_1C11_singleread<f...
# 1299092      NaN     NaN            cuLaunchKernel (weight_decay [1183561])
# 1299865      1.0     7.0                             weight_decay [1183561]
# 1321024      NaN     NaN            cuLaunchKernel (momentum_sgd [1203561])
# 1321588      1.0     7.0                             momentum_sgd [1203561]
# 1342956      NaN     NaN            cuLaunchKernel (momentum_sgd [1223561])
# 1343303      1.0     7.0                             momentum_sgd [1223561]
# 1356285      NaN     NaN  cudaLaunch (maxwell_scudnn_128x128_stridedB_sp...
# 1357627      1.0     7.0  maxwell_scudnn_128x128_stridedB_splitK_small_n...
# 1366456      1.0     7.0  void cudnn::detail::bn_fw_tr_1C11_kernel_new<f...
# 1466704      1.0     7.0  void cudnn::detail::bn_fw_inf_1C11_kernel_new<...
# 1475137      NaN     NaN            cuLaunchKernel (cupy_maximum [1343561])
# 1475252      1.0     7.0                             cupy_maximum [1343561]
#
# [69 rows x 19 columns]

# %%
for col in nvprof:
    print col
# Out:
# Start (s)
# Duration (ms)
# Grid X
# Grid Y
# Grid Z
# Block X
# Block Y
# Block Z
# Registers Per Thread
# Static SMem (KB)
# Dynamic SMem (KB)
# Size (MB)
# Throughput (GB/s)
# SrcMemType
# DstMemType
# Device
# Context
# Stream
# Name
